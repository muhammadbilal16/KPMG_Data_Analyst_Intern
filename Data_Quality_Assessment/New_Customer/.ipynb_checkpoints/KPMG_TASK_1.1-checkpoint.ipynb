# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x000001C6D9FC5110>

# %%
xlsx = pd.ExcelFile('KPMG_VI_New_raw_data_update_final.xlsx')
New_Customer_List = pd.read_excel(xlsx, sheet_name=2, header=1)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2560\4112865240.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   New_Customer_List = pd.read_excel(xlsx, sheet_name=2, header=1)

# %%
df = pd.DataFrame(New_Customer_List)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
# First Three Records
df.head(n=3)
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
#
#          DOB               job_title job_industry_category     wealth_segment  \
# 0 1957-07-12         General Manager         Manufacturing      Mass Customer
# 1 1970-03-22     Structural Engineer              Property      Mass Customer
# 2 1974-08-28  Senior Cost Accountant    Financial Services  Affluent Customer
#
#   deceased_indicator owns_car  ...  state    country  property_valuation  \
# 0                  N      Yes  ...    QLD  Australia                   6
# 1                  N       No  ...    NSW  Australia                  11
# 2                  N       No  ...    VIC  Australia                   5
#
#   Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Rank  \
# ...

# %%
# LAST 5 Records
df.tail()
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# 995 1959-10-07                     Paralegal    Financial Services
# 996 2001-10-17        Senior Sales Associate                Health
# 997 1954-10-05  Budget/Accounting Analyst IV    Financial Services
# 998 1952-12-17             Financial Advisor    Financial Services
# 999 1955-10-02           Staff Accountant IV              Property
#
#         wealth_segment deceased_indicator owns_car  ...  state    country  \
# ...

# %%
# Check for Null values
df.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
# Droping The Unamed Cols
un_named_cols = ['Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20']
df_1 = df.drop(un_named_cols,axis=1)

# %%
# CheckPoint
df_2 = df_1.copy()

# %%
# Sort by Fisrt Name and Then Filled the last name
df_2['last_name'] = df_2.groupby('first_name').last_name.bfill().ffill()

# %%
check_data = df_2[['gender','state','country','job_title','job_industry_category']]
for check in check_data:
    print(check, df_2[check].value_counts())
# Out:
# gender Female    513
# Male      470
# U          17
# Name: gender, dtype: int64
# state NSW    506
# VIC    266
# QLD    228
# Name: state, dtype: int64
# country Australia    1000
# Name: country, dtype: int64
# job_title Associate Professor         15
# Environmental Tech          14
# Software Consultant         14
# Chief Design Engineer       13
# Assistant Manager           12
#                             ..
# Accountant II                1
# Programmer IV                1
# Administrative Officer       1
# Accounting Assistant III     1
# Web Developer I              1
# Name: job_title, Length: 184, dtype: int64
# job_industry_category Financial Services    203
# Manufacturing         199
# Health                152
# Retail                 78
# Property               64
# IT                     51
# Entertainment          37
# Argiculture            26
# Telecommunications     25
# Name: job_industry_category, dtype: int64

# %%
df_2['address'].nunique()
# Out:
# 1000

# %%
# date format checking 
df_2['DOB'] = df['DOB'].dt.date
df_2['DOB']
# Out:
# 0      1957-07-12
# 1      1970-03-22
# 2      1974-08-28
# 3      1979-01-28
# 4      1965-09-21
#           ...
# 995    1959-10-07
# 996    2001-10-17
# 997    1954-10-05
# 998    1952-12-17
# 999    1955-10-02
# Name: DOB, Length: 1000, dtype: object

# %%
# filling DOB with exisiting data
df_2['DOB'].fillna(lambda x: np.random.choice(df4['DOB']), inplace=True)

# %%
# checking frequency of job title and then fill according to freq
df_2['job_title'].value_counts()
# Out:
# Associate Professor         15
# Environmental Tech          14
# Software Consultant         14
# Chief Design Engineer       13
# Assistant Manager           12
#                             ..
# Accountant II                1
# Programmer IV                1
# Administrative Officer       1
# Accounting Assistant III     1
# Web Developer I              1
# Name: job_title, Length: 184, dtype: int64

# %%
# we will fill by backward filling
df_2['job_title'] = df_2['job_title'].fillna(method='bfill')

# %%
# check freq of job industries 
df_2['job_industry_category'].value_counts()
# Out:
# Financial Services    203
# Manufacturing         199
# Health                152
# Retail                 78
# Property               64
# IT                     51
# Entertainment          37
# Argiculture            26
# Telecommunications     25
# Name: job_industry_category, dtype: int64

# %%
# Now we will fill by forward filling
df_2['job_industry_category'] = df_2['job_industry_category'].fillna(method='ffill')

# %%
# make sure that the column names are in the correct format
df_2.columns = map(str.lower, df_2.columns)
df_2.columns = map(str.strip, df_2.columns)

# %%
# round the values to the correct format
df_2['value'] = df_2['value'].round(3)
df_2
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#             dob                     job_title job_industry_category  \
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            1000 non-null   object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   dob                                  1000 non-null   object
#  5   job_title                            1000 non-null   object
#  6   job_industry_category                1000 non-null   object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
#print to csv file after the cleaning
df_2.to_csv('New_Cutomer_list_cleaned.csv',index=False)
